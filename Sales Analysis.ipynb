# %%
import pandas as pd

#Read the uploaded CSV file

df = pd.read_csv('sales_data_sample.csv', encoding = 'ISO-8859-1')

#showe the first 5 rows
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
# cleaning and preparing the data
# Keep only two columns we need (date & Sales)

df =df[['ORDERDATE', 'SALES']]


#Convert the 'ORDERDATE' column to datetime format (e.g., 2/24/2003 → 2003-02-24)
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])

# Group sales by date (add sales from same date)
df = df.groupby('ORDERDATE').sum()

# Sort by date (from oldest to newest)
df = df.sort_index()

#View the first few rows
print(df.head())
# Out:
#                SALES
# ORDERDATE
# 2003-01-06  12133.25
# 2003-01-09  11432.34
# 2003-01-10   6864.05
# 2003-01-29  54702.00
# 2003-01-31  44621.96

# %%
# Visualize Daily Sales

# Import the matplotlib library for plotting
import matplotlib.pyplot as plt
# Set the figure size (width=14, height=6) so the graph is large and clear
plt.figure(figsize=(14, 6))

# Plot sales over time; x = date, y = sales values
plt.plot(df.index, df['SALES'], color='blue', label='Daily Sales')

# Set a title for the chart
plt.title('Daily Sales Trend')

# Label for the X-axis
plt.xlabel('Date')

# Label for the Y-axis
plt.ylabel('Sales ($)')

# Add grid lines for better readability
plt.grid(True)

# Show the legend (Daily Sales label)
plt.legend()

# Adjust layout so nothing gets cut off
plt.tight_layout()

# Finally, display the plot
plt.show()

# %%
# Apply Moving Averages?

# Add 7-day moving average (rolling mean)
df['7-day MA'] = df['SALES'].rolling(window=7).mean()

# Add 30-day moving average
df['30-day MA'] = df['SALES'].rolling(window=30).mean()

# Create a new plot
plt.figure(figsize=(12, 6))

# Plot original daily sales
plt.plot(df['SALES'], label='Original', color='lightgray')

# Plot 7-day moving average
plt.plot(df['7-day MA'], label='7-Day MA', color='blue')

# Plot 30-day moving average
plt.plot(df['30-day MA'], label='30-Day MA', color='green')

# Add a title and legend
plt.title('Sales with Moving Averages')
plt.legend()

# Show the chart
plt.show()

# %%
# !pip install --upgrade statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\havannah\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\havannah\anaconda3\lib\site-packages (from statsmodels) (1.9.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\havannah\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy<2,>=1.18 in c:\users\havannah\anaconda3\lib\site-packages (from statsmodels) (1.20.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in c:\users\havannah\anaconda3\lib\site-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\havannah\anaconda3\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\havannah\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\havannah\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\havannah\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\havannah\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas!=2.1.0,>=1.0->statsmodels) (1.16.0)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)

# %%
#Decompose Time Seriers for Seasonality

# Import the seasonal decomposition function
from statsmodels.tsa.seasonal import seasonal_decompose

# Convert daily sales to monthly total sales
monthly_sales = df['SALES'].resample('M').sum()

# Break the monthly sales data into trend, seasonality, and noise
result = seasonal_decompose(monthly_sales, model='additive')

# Plot the result
result.plot()  # Creates 4 subplots: observed, trend, seasonal, residual
plt.suptitle('Time Series Decomposition of Monthly Sales', fontsize=16)  # Add title
plt.tight_layout()  # Prevents label cutoff
plt.show()  # Show the chart

# %%
#Detect Anomalies

# Calculate threshold for anomaly detection
mean_sales = df['SALES'].mean()  # Average sales
std_sales = df['SALES'].std()    # Spread/variation in sales
threshold = mean_sales + 2 * std_sales  # Set threshold at 2 standard deviations above mean

# Identify days where sales exceed this threshold
anomalies = df[df['SALES'] > threshold]  # These are the anomaly days

# Visualize daily sales and mark anomalies
plt.figure(figsize=(14, 6))
plt.plot(df.index, df['SALES'], label='Daily Sales', color='lightgray')  # Main sales line
plt.scatter(anomalies.index, anomalies['SALES'], color='red', label='Anomalies', zorder=5)  # Red dots for anomalies

# Add horizontal line for the anomaly threshold
plt.axhline(y=threshold, color='orange', linestyle='--', label='Anomaly Threshold')

plt.title('Anomaly Detection in Sales')
plt.xlabel('Date')
plt.ylabel('Sales ($)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Optional: Display the dates and values of anomalies
print("Unusual Sales Days:")
print(anomalies[['SALES']])
# Out:
# Unusual Sales Days:
#                 SALES
# ORDERDATE
# 2003-11-06  114456.85
# 2003-11-12  111156.73
# 2003-11-14  131236.00
# 2003-11-20   95344.63
# 2003-12-02  109432.27
# 2004-08-20   96139.50
# 2004-09-08   93717.43
# 2004-10-16  103815.53
# 2004-10-22   96850.65
# 2004-11-04  105074.98
# 2004-11-05  106240.69
# 2004-11-17   97958.38
# 2004-11-24  137644.72
# 2004-12-10   93587.56
# 2005-02-17   92236.97

# %%
# Forecaste Sales using Prophet Model
# !pip install prophet
# Out:
# Collecting prophet
#   Using cached prophet-1.2.1-py3-none-win_amd64.whl (12.1 MB)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\havannah\anaconda3\lib\site-packages (from prophet) (3.5.2)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\havannah\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Collecting holidays<1,>=0.25
#   Using cached holidays-0.58-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: importlib_resources in c:\users\havannah\anaconda3\lib\site-packages (from prophet) (5.2.0)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\havannah\anaconda3\lib\site-packages (from prophet) (1.4.4)
# Collecting cmdstanpy>=1.0.4
#   Using cached cmdstanpy-1.2.5-py3-none-any.whl (94 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\havannah\anaconda3\lib\site-packages (from prophet) (1.24.4)
# Collecting stanio<2.0.0,>=0.4.0
#   Using cached stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: python-dateutil in c:\users\havannah\anaconda3\lib\site-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\havannah\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\havannah\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\havannah\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\havannah\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\havannah\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\havannah\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\havannah\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2022.1)
# Requirement already satisfied: colorama in c:\users\havannah\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\havannah\anaconda3\lib\site-packages (from importlib_resources->prophet) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\havannah\anaconda3\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Installing collected packages: stanio, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.5 holidays-0.58 prophet-1.2.1 stanio-0.5.1
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\havannah\anaconda3\lib\site-packages)

# %%
# import prophet

from prophet import Prophet

# Prepare monthly data (we'll forecast based on monthly sales totals)
monthly_df = df['SALES'].resample('M').sum().reset_index()

# Prophet expects columns named 'ds' for date and 'y' for value
monthly_df.columns = ['ds', 'y']

# Let's see the first few rows
monthly_df.head()
# Out:
# Importing plotly failed. Interactive plots will not work.
#           ds          y
# 0 2003-01-31  129753.60
# 1 2003-02-28  140836.19
# 2 2003-03-31  174504.90
# 3 2003-04-30  201609.55
# 4 2003-05-31  192673.11

# %%
# Train the Prophet Model and Forecast Future Sales
# Create and fit the model
model = Prophet()               # Initialize Prophet model
model.fit(monthly_df)           # Fit the model to our sales data

# Create future dates (12 more months from the last date in the dataset)
future = model.make_future_dataframe(periods=12, freq='M')  # Add 12 future months

# Predict future sales using the trained model
forecast = model.predict(future)  # Generate forecast for all dates (past + future)
# Out:
# 21:53:20 - cmdstanpy - INFO - Chain [1] start processing
# 21:53:21 - cmdstanpy - INFO - Chain [1] done processing

# %%
#Plot the forecast
fig = model.plot(forecast)          # Prophet's built-in forecast plot
plt.title("Monthly Sales Forecast") # Add title
plt.xlabel("Date")                  # X-axis label
plt.ylabel("Sales")                 # Y-axis label
plt.grid(True)                      # Add grid for clarity
plt.show()
